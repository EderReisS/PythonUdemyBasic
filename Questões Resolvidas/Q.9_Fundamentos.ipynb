# %% [markdown]
# # 9)
# Escreva um script para classificar um triângulo de acordo com o tamanho dos seus lados.

# %%
print("Por favor, digite os comprimento doas lados a, b e c respectivamente:")
a = input("a = ")
b = input("b = ")
c = input("c = ")

if a==b==c:
  print("O triângulo é equilátero")
elif a==b or a==c or b==c:
  print("O triângulo é isóceles")
else:
   print("O triângulo é escaleno")
# Out:
# Por favor, digite os comprimento doas lados a, b e c respectivamente:
# a = 1
# b = 2
# c = 2
# O triângulo é isóceles

# %%
if '2'=='1'=='2':
  print("1")
