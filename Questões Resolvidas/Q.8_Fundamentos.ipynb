# %% [markdown]
# # 8)
# Escreva um script que mostre na tela o preço de um produto associado a uma categoria especificada pelo usuário. Utilize como referência as informações a seguir. Caso o usuário não digite uma categoria válida (número entre 1 e 10) mostre na tela uma mensagem personalizada.

# %%
a1 = input("Digite a categoria do produto entre 1 à 10:")
dict_a1 = {'1':'$ 0,5', '2': '$ 11,3','3':'$ 17,5', '4':'$ 33,97', '5' :'$ 103,47' ,'6':'$ 44,67','7':'$ 12,55', '8':'$ 14,87'
,'9':'$ 98,12','10':'$ 131,4'}

a1 = a1.strip()

if a1 not in dict_a1:
  print(f"{a1} não é uma chave válida!")
else:
  print(f" *categoria {a1} - {dict_a1[a1]} ")
# Out:
# Digite um número inteiro entre 1 à 10:3
#  *categoria 3 - $ 17,5

# %%
print(f"{dict_a1[a1]}")
# Out:
# $ 11,3
