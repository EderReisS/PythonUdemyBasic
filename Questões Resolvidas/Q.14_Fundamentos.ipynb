# %% [markdown]
# # 14)
# Mude a chave 'valor' do dicionário produto1 para 99.98.
#
# produto1={
#     'nome':'produto1',
#     'tipo':'categoriaA',
#     'valor':'50.5',
#     'fornecedor':'ABCD',
# }

# %%
produto1={
    'nome':'produto1',
    'tipo':'categoriaA',
    'valor':'50.5',
    'fornecedor':'ABCD',
}

# %%
produto1['nome'] = 99.98

# %%
print(produto1)
# Out:
# {'nome': 99.98, 'tipo': 'categoriaA', 'valor': '50.5', 'fornecedor': 'ABCD'}
