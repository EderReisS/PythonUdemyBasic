# %% [markdown]
# # Exercício 4) Udemy Fundamentos Python

# %%
A1 = input("Por favor, digite um número inteiro: ")
A1 = int(A1)

if A1%2 == 0:
  A2 = "par"
else:
  A2= "ímpar"
print(f"O número {A1} é {A2}!")
# Out:
# Por favor, digite um número inteiro: 1234567890
# O número 1234567890 é par!
