# %% [markdown]
# # 7)
# Escreva um programa que inverta uma string. Exemplos:
#
# Hello World!
#
# Python
#
# !dlroW olleH
#
# nohtyP

# %%
A1=input("String: ")
print(A1[::1])
# Out:
# String: Alpha zero 1
# Alpha zero 1
