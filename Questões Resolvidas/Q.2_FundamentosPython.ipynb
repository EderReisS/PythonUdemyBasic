# %% [markdown]
# Exercício Udemy 2) Soma de dois números

# %%
print("Por favor, digite dois números para obter o montante, A+B = M")
A = input(" A = ")
B = input(" B = ")
A = float(A)
B = float(B)
M = A + B
print(f" O resultado da soma é {M}")
# Out:
# Por favor, digite dois números para obter o montante, A+B = M
#  A = 12
#  B = 10
#  O resultado da soma é 22.0
