# %% [markdown]
# #Exercício 3) Udemy

# %%
print("Por favor, insira seu nome e sua idade.")
Nome = input("Nome: ")
idade = input("Idade: ")
Nome = Nome.strip()
idade = int(idade)
if (idade >= 18):
  print(f" Seja bem-vindo ao nosso site {Nome}!")
else:
  print(f"Você não pode acessar nosso site {Nome}.")
# Out:
# Por favor, insira seu nome e sua idade.
# Nome: Josefa Paladd
# Idade: 234
#  Seja bem-vindo ao nosso site Josefa Paladd!
