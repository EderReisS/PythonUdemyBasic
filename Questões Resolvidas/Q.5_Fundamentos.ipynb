# %%
print("Por favor, insira sua altura e peso para prosseguir o cálculo do IMC")
Altura = input("Digite sua altura em metros: ")
Peso = input("Digite seu peso em kg: ")
Altura = float(Altura)
Peso = float(Peso)
IMC = Peso/(Altura**2)
if IMC < 17 :
  print("Muito abaixo do peso ideal")
else:
  if IMC < 18.5:
    print("Abaixo do peso")
  else:
    if IMC < 25:
      print("Peso normal")
    else:
      if IMC < 30:
        print("Acima do Peso")
      else:
        if IMC < 35:
           print("Obesidade I")
        else:
          if IMC <40:
            print("Obesidade II (severa)")
          else:
            print("Obesidade III (mórbida)")
# Out:
# Por favor, insira sua altura -em metros- e seu peso -em kg- para prosseguir o cálculo do IMC
# Digite sua altura: 1.75
# Digite seu peso: 129
# Obesidade III (mórbida)
