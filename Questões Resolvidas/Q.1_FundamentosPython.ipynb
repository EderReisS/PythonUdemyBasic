# %% [markdown]
# Exercício Udemy 1) Seu nome informado
#
# ```
# # Isto está formatado como código
# ```

# %%
Nome = input(" Por favor, insira seu nome: ")
SobreNome = input(" Agora, seu sobrenome: ")
Nome = Nome.upper().strip()
SobreNome = SobreNome.upper().strip()
print(f"{Nome} {SobreNome}, seu nome foi armazenado com sucesso!")
# Out:
#  Por favor, insira seu nome: Pedro
#  Agora, seu sobrenome: Reis
# PEDRO REIS, seu nome foi armazenado com sucesso!
